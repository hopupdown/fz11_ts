# %%
import os
from os import path
import pandas as pd
import numpy as np
import statsmodels.tsa.api as smt
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from scipy.stats import boxcox
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_squared_error, r2_score
from statsmodels.tsa.ar_model import AutoReg, ar_select_order

# %%
df = pd.read_csv(os.path.join("data","Monthly beer production in Australia megalitres Includes ale and stout.csv"),index_col=0)

df.head()
# Out:
#       x
# 1  93.2
# 2  96.0
# 3  95.2
# 4  77.1
# 5  70.9

# %%
df.head()
# Out:
#       x
# 1  93.2
# 2  96.0
# 3  95.2
# 4  77.1
# 5  70.9

# %%
df.describe()
# Out:
#                 x
# count  476.000000
# mean   136.395378
# std     33.738725
# min     64.800000
# 25%    112.900000
# 50%    139.150000
# 75%    158.825000
# max    217.800000

# %%
plt.plot(df)

# %%
def adfuller_get_p(ts):
    return adfuller(ts)[1]

def adfuller_print(ts,name = ""):
    alpha = 0.05

    dftest = adfuller(ts)

    dfoutput = pd.Series(dftest[0:4],index=["Test Statistic","p-value","Lags","Number of Observations"])

    for key,value in dftest[4].items():
        dfoutput["Critical Value (%s)"%key] = value

    print(f"Проверка на стационарность для ряда {name}")
    print(dfoutput)
    if dfoutput["p-value"] < alpha:
        print(f"Значение p меньше {alpha * 100}%. Ряд стационарный.")
    else:
        print(f"Значение p больше {alpha * 100}%. Ряд не стационарный.")

# %%
adfuller_print(df["x"],"Пиво")
# Out:
# Проверка на стационарность для ряда Пиво
# Test Statistic             -2.282661
# p-value                     0.177621
# Lags                       17.000000
# Number of Observations    458.000000
# Critical Value (1%)        -3.444709
# Critical Value (5%)        -2.867871
# Critical Value (10%)       -2.570142
# dtype: float64
# Значение p больше 5.0%. Ряд не стационарный.

# %%
def delete_trend(ts):
    nottrend = []
    for i in range(1,len(ts)):
        nottrend.append(ts[i] - ts[i-1])
    return nottrend

# %%
def delete_seson(ts,s):
    notseson = []
    for i in range(s,len(ts)):
        notseson.append(ts[i] - ts[i-s])
    return notseson

# %%
nottrend = []
s = 12
notseson = []

ts = df["x"].to_numpy()

nottrend = delete_trend(ts)

notseson = delete_seson(ts,s)

# %%
plt.plot(nottrend)

# %%
plt.plot(notseson)

# %%
adfuller_print(nottrend)
# Out:
# Проверка на стационарность для ряда
# Test Statistic             -4.980664
# p-value                     0.000024
# Lags                       18.000000
# Number of Observations    456.000000
# Critical Value (1%)        -3.444772
# Critical Value (5%)        -2.867899
# Critical Value (10%)       -2.570157
# dtype: float64
# Значение p меньше 5.0%. Ряд стационарный.

# %%
adfuller_print(notseson)
# Out:
# Проверка на стационарность для ряда
# Test Statistic             -2.896762
# p-value                     0.045726
# Lags                       17.000000
# Number of Observations    446.000000
# Critical Value (1%)        -3.445097
# Critical Value (5%)        -2.868042
# Critical Value (10%)       -2.570233
# dtype: float64
# Значение p меньше 5.0%. Ряд стационарный.

# %%
def autocor_print(ts,lags_autocor,lags_part_autocor):
    fig = plt.figure(figsize=(20,9))
    layout = (2,2)
    ts_ax = plt.subplot2grid(layout,(0,0), colspan=2)
    acf_ax = plt.subplot2grid(layout,(1,0))
    pacf_ax = plt.subplot2grid(layout,(1,1))

    ts.plot(ax=ts_ax)
    ts_ax.set_title("Time Series Analysis Plots")
    smt.graphics.plot_acf(ts,lags=lags_autocor,ax=acf_ax,alpha=0.5)
    smt.graphics.plot_pacf(ts,lags=lags_part_autocor,ax=pacf_ax,alpha=0.5)
    None

# %%
ts = pd.DataFrame(df["x"])

autocor_print(ts,24,24)

# %%
df.index = df.index - 1

df["t"] = df.index.values



ln = len(df)

train_cutoff = int(round(ln*0.75,0))
validate_cutoff = int(round(ln*0.9,0))

train_df = df[df["t"] <= train_cutoff]
validate_df = df[(df["t"] > train_cutoff) & (df["t"] <= validate_cutoff)]

forecast_df = df[df["t"] > validate_cutoff]

# %%
plt.plot(train_df.t,train_df.x,label="Training data")
plt.plot(validate_df.t,validate_df.x,label="Validate data")
plt.plot(forecast_df.t,forecast_df.x,label="for prediction")
plt.legend()
plt.title("Beer by month")
plt.ylabel("Total passengers")
plt.xlabel("Month")
plt.show()

# %%
sel = ar_select_order(df.x,24,old_names=False)
res = sel.model.fit()
print(res.summary())
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                      x   No. Observations:                  476
# Model:                    AutoReg(24)   Log Likelihood               -1663.331
# Method:               Conditional MLE   S.D. of innovations              9.593
# Date:                Wed, 11 Oct 2023   AIC                           3378.662
# Time:                        09:51:22   BIC                           3485.618
# Sample:                            24   HQIC                          3420.809
#                                   476
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.1890      2.481      2.091      0.037       0.325      10.053
# x.L1          -0.0227      0.046     -0.495      0.621      -0.113       0.067
# x.L2          -0.0990      0.046     -2.161      0.031      -0.189      -0.009
# x.L3           0.0491      0.045      1.085      0.278      -0.040       0.138
# x.L4          -0.0190      0.045     -0.424      0.671      -0.107       0.069
# x.L5           0.1765      0.044      3.985      0.000       0.090       0.263
# x.L6           0.0055      0.045      0.122      0.903      -0.083       0.094
# x.L7           0.0217      0.045      0.486      0.627      -0.066       0.109
# x.L8           0.1939      0.045      4.340      0.000       0.106       0.282
# x.L9           0.1931      0.045      4.284      0.000       0.105       0.281
# x.L10          0.0618      0.046      1.344      0.179      -0.028       0.152
# x.L11          0.3420      0.045      7.527      0.000       0.253       0.431
# x.L12          0.5066      0.048     10.535      0.000       0.412       0.601
# x.L13          0.0609      0.049      1.256      0.209      -0.034       0.156
# x.L14          0.1529      0.046      3.337      0.001       0.063       0.243
# x.L15         -0.0102      0.046     -0.219      0.827      -0.101       0.081
# x.L16         -0.1369      0.045     -3.015      0.003      -0.226      -0.048
# x.L17          0.0196      0.045      0.435      0.663      -0.069       0.108
# x.L18         -0.1238      0.045     -2.750      0.006      -0.212      -0.036
# x.L19         -0.0549      0.045     -1.210      0.226      -0.144       0.034
# x.L20         -0.1404      0.045     -3.150      0.002      -0.228      -0.053
# x.L21         -0.1627      0.045     -3.611      0.000      -0.251      -0.074
# x.L22         -0.1961      0.046     -4.309      0.000      -0.285      -0.107
# x.L23         -0.0700      0.046     -1.512      0.131      -0.161       0.021
# x.L24          0.2200      0.046      4.742      0.000       0.129       0.311
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -1.0994           -0.0000j            1.0994           -0.5000
# AR.2            -1.0621           -0.2622j            1.0940           -0.4615
# AR.3            -1.0621           +0.2622j            1.0940            0.4615
# AR.4            -0.8827           -0.5083j            1.0186           -0.4168
# AR.5            -0.8827           +0.5083j            1.0186            0.4168
# AR.6            -0.7371           -0.8084j            1.0940           -0.3677
# AR.7            -0.7371           +0.8084j            1.0940            0.3677
# AR.8            -0.5719           -0.8536j            1.0275           -0.3439
# AR.9            -0.5719           +0.8536j            1.0275            0.3439
# AR.10           -0.2621           -1.0495j            1.0817           -0.2889
# AR.11           -0.2621           +1.0495j            1.0817            0.2889
# AR.12           -0.0018           -1.0132j            1.0132           -0.2503
# AR.13           -0.0018           +1.0132j            1.0132            0.2503
# AR.14            0.2652           -1.0259j            1.0596           -0.2097
# AR.15            0.2652           +1.0259j            1.0596            0.2097
# AR.16            0.5028           -0.8743j            1.0085           -0.1669
# AR.17            0.5028           +0.8743j            1.0085            0.1669
# AR.18            0.7921           -0.7327j            1.0790           -0.1188
# AR.19            0.7921           +0.7327j            1.0790            0.1188
# AR.20            0.8668           -0.5008j            1.0011           -0.0834
# AR.21            0.8668           +0.5008j            1.0011            0.0834
# AR.22            1.0061           -0.0000j            1.0061           -0.0000
# AR.23            1.0858           -0.0000j            1.0858           -0.0000
# AR.24            1.5071           -0.0000j            1.5071           -0.0000
# ------------------------------------------------------------------------------

# %%
fig = res.plot_predict(0)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pred = res.predict(start=0,end=train_cutoff,dynamic=False)
v_pred = res.predict(start=train_cutoff+1,end=validate_cutoff,dynamic=False)
f_pred = res.predict(start=validate_cutoff+1,end=(forecast_df.t[len(df.t)-1]))

# %%
plt.plot(train_df.t,train_df.x,label="Training data")
plt.plot(validate_df.t,validate_df.x,label="Validate data")
plt.plot(forecast_df.t,forecast_df.x,label="for prediction")
plt.plot(train_df.t,pred,label="Training prediction")
plt.plot(validate_df.t,v_pred,label="Validate prediction")
plt.plot(forecast_df.t,f_pred,label="Forecast prediction")
plt.legend()
plt.title("Beer by month")
plt.ylabel("Total passengers")
plt.xlabel("Month")
plt.show()

# %%
def SMAPE(y_true, y_pred):
    numerator = np.abs(y_true-y_pred)
    denumerator = (np.abs(y_true) + np.abs(y_pred))/2
    res = numerator/denumerator
    res = np.sum(res)
    res *= 100
    res /= len(y_true)
    return res

# %%
print("RMSE:", np.sqrt(mean_squared_error(forecast_df.x, f_pred)))
print("MAPE:", mean_absolute_percentage_error(forecast_df.x, f_pred))
print("MAE:", mean_absolute_error(forecast_df.x, f_pred))
print("R2: ", r2_score(forecast_df.x, f_pred))
print("SMAPE", SMAPE(forecast_df.x, f_pred))
# Out:
# RMSE: 8.515438370827288
# MAPE: 0.04712497767684922
# MAE: 6.870976633092662
# R2:  0.8304415262963873
# SMAPE 4.655031746305231
